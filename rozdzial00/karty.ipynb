# %%
#prepare 
import random
suits = ["trefl","pik","kler","karo"]
faces = ["walet","dama","krol","as"]
numbers = [2,3,4,5,6,7,8,9,10]

# %%
suits
# Out:
# ['trefl', 'pik', 'kler', 'karo']

# %%
def draw():
    the_suit = random.choice(suits)
    the_card = random.choice(faces + numbers)
    return the_card, " ", the_suit

# %%
draw()
# Out:
# ('krol', ' ', 'karo')

# %%
print(draw())
# Out:
# ('walet', ' ', 'kler')

# %%
for _ in range(5):
    print(draw())
# Out:
# ('as', ' ', 'trefl')
# (10, ' ', 'karo')
# (7, ' ', 'pik')
# (6, ' ', 'karo')
# ('as', ' ', 'pik')

# %%
#let's add our cards to deck
deck = set()

# %%
type(deck)
# Out:
# set

# %%
len(deck)
# Out:
# 0

# %%
print(dir(deck))
# Out:
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
help(deck.add)
# Out:
# Help on built-in function add:
#
# add(object, /) method of builtins.set instance
#     Add an element to a set.
#
#     This has no effect if the element is already present.

# %%
for suit in suits:
    for card in faces + numbers:
        deck.add((card," ", suit))

# %%
len(deck)
# Out:
# 52

# %%
print(deck)
# Out:
# {(5, ' ', 'kler'), (7, ' ', 'trefl'), (5, ' ', 'pik'), (10, ' ', 'karo'), (3, ' ', 'kler'), (6, ' ', 'trefl'), (7, ' ', 'karo'), ('as', ' ', 'trefl'), (3, ' ', 'trefl'), (4, ' ', 'trefl'), ('krol', ' ', 'pik'), (2, ' ', 'pik'), ('krol', ' ', 'kler'), (2, ' ', 'kler'), (6, ' ', 'karo'), ('walet', ' ', 'kler'), (5, ' ', 'trefl'), ('as', ' ', 'karo'), (9, ' ', 'pik'), (9, ' ', 'kler'), (3, ' ', 'karo'), ('walet', ' ', 'pik'), (4, ' ', 'karo'), ('dama', ' ', 'pik'), (8, ' ', 'pik'), ('dama', ' ', 'kler'), (8, ' ', 'kler'), (4, ' ', 'kler'), (5, ' ', 'karo'), (10, ' ', 'pik'), (2, ' ', 'trefl'), ('krol', ' ', 'trefl'), (10, ' ', 'kler'), (9, ' ', 'trefl'), (7, ' ', 'pik'), (7, ' ', 'kler'), ('walet', ' ', 'trefl'), ('krol', ' ', 'karo'), ('dama', ' ', 'trefl'), (8, ' ', 'trefl'), (6, ' ', 'pik'), (6, ' ', 'kler'), (2, ' ', 'karo'), ('as', ' ', 'kler'), (9, ' ', 'karo'), ('as', ' ', 'pik'), ('walet', ' ', 'karo'), (3, ' ', 'pik'), (10, ' ', 'trefl'), ('dama', ' ', 'karo'), (8, ' ', 'karo'), (4, ' ', 'pik')}

# %%
card = random.choice(list(deck))
print(card)
# Out:
# (4, ' ', 'pik')

# %%
help(deck.remove)
# Out:
# Help on built-in function remove:
#
# remove(object, /) method of builtins.set instance
#     Remove an element from a set; it must be a member.
#
#     If the element is not a member, raise a KeyError.

# %%
deck.remove(card)
len(deck)
# Out:
# 50

# %%
type(card)
# Out:
# tuple

# %%
def draw():
    card = random.choice(list(deck))
    deck.remove(card)
    return card

# %%
print(draw())
# Out:
# (2, ' ', 'trefl')

# %%
len(deck)
# Out:
# 49
